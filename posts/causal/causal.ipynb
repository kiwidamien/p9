# %% [markdown]
# ---
# title: "Difference-in-difference vs Synthetic Controls"
# author: "Damien Martin"
# date: "2025-11-19 12:00"
# categories: [causal, did, synthetic controsl]
# image: "image.jpg"
# description: "A set of notes for myself on Synthetic Controls vs Difference-in-difference"
# ---

# %% [markdown]
# # Overview
